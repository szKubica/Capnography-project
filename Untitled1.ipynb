# %%
import pandas as pd
import plotly.express as px
import matplotlib as plt
df=pd.read_csv(r"C:\Users\Lenovo\Downloads\Dane1.csv")
df.drop(columns=['RESP', '125','17.11.21','14:39:09' ], inplace=True)
df.drop(df.index[130000:], inplace=True)
df.drop(df.index[:125799], inplace=True)
df.insert(0, 'Lp', range(1, 4202))
df['ETCO2']=df['ETCO2'].astype(str).astype(int)
print(df.dtypes)
p=df.plot(x='Lp', y='ETCO2')
# Out:
# Lp          int64
# EKG II     object
# EKG III    object
# ETCO2       int32
# dtype: object
